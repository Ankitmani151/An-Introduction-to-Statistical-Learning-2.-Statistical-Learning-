# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("College.csv")

# %%
df.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
# Renaming college name
new="College_name"
df = df.rename(columns={'Unnamed: 0':new})

# %%
df.head()
# Out:
#                    College_name Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
df.columns
# Out:
# Index(['College_name', 'Private', 'Apps', 'Accept', 'Enroll', 'Top10perc',
#        'Top25perc', 'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board',
#        'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni',
#        'Expend', 'Grad.Rate'],
#       dtype='object')

# %%
# checking data types
df.dtypes
# Out:
# College_name     object
# Private          object
# Apps              int64
# Accept            int64
# Enroll            int64
# Top10perc         int64
# Top25perc         int64
# F.Undergrad       int64
# P.Undergrad       int64
# Outstate          int64
# Room.Board        int64
# Books             int64
# Personal          int64
# PhD               int64
# Terminal          int64
# S.F.Ratio       float64
# perc.alumni       int64
# Expend            int64
# Grad.Rate         int64
# dtype: object

# %%
#Checking missing values, Data type and unique values in the dataset
def Missing_Values(data):
    variable_name=[]
    total_value=[]
    total_missing_value=[]
    missing_value_rate=[]
    unique_value_list=[]
    total_unique_value=[]
    data_type=[]
    for col in data.columns:
        variable_name.append(col)
        data_type.append(data[col].dtype)
        total_value.append(data[col].shape[0])
        total_missing_value.append(data[col].isnull().sum())
        missing_value_rate.append(round(data[col].isnull().sum()/data[col].shape[0],5))
        unique_value_list.append(data[col].unique())
        total_unique_value.append(len(data[col].unique()))
    missing_data=pd.DataFrame({"Variable":variable_name,"Total_Value":total_value,\
                             "Total_Missing_Value":total_missing_value,"Missing_Value_Rate":missing_value_rate,
                             "Data_Type":data_type,"Unique_Value":unique_value_list,\
                               "Total_Unique_Value":total_unique_value})
    
    return missing_data.sort_values("Missing_Value_Rate",ascending=False)

# %%
Missing_Values(df)
# Out:
#         Variable  Total_Value  Total_Missing_Value  Missing_Value_Rate  \
# 0   College_name          777                    0                 0.0
# 10    Room.Board          777                    0                 0.0
# 17        Expend          777                    0                 0.0
# 16   perc.alumni          777                    0                 0.0
# 15     S.F.Ratio          777                    0                 0.0
# 14      Terminal          777                    0                 0.0
# 13           PhD          777                    0                 0.0
# 12      Personal          777                    0                 0.0
# 11         Books          777                    0                 0.0
# 9       Outstate          777                    0                 0.0
# 1        Private          777                    0                 0.0
# 8    P.Undergrad          777                    0                 0.0
# ...

# %%
df.shape
# Out:
# (777, 19)

# %%
# Summary of the dataset
df.describe().transpose()
# Out:
#              count          mean          std     min     25%     50%  \
# Apps         777.0   3001.638353  3870.201484    81.0   776.0  1558.0
# Accept       777.0   2018.804376  2451.113971    72.0   604.0  1110.0
# Enroll       777.0    779.972973   929.176190    35.0   242.0   434.0
# Top10perc    777.0     27.558559    17.640364     1.0    15.0    23.0
# Top25perc    777.0     55.796654    19.804778     9.0    41.0    54.0
# F.Undergrad  777.0   3699.907336  4850.420531   139.0   992.0  1707.0
# P.Undergrad  777.0    855.298584  1522.431887     1.0    95.0   353.0
# Outstate     777.0  10440.669241  4023.016484  2340.0  7320.0  9990.0
# Room.Board   777.0   4357.526384  1096.696416  1780.0  3597.0  4200.0
# Books        777.0    549.380952   165.105360    96.0   470.0   500.0
# Personal     777.0   1340.642214   677.071454   250.0   850.0  1200.0
# PhD          777.0     72.660232    16.328155     8.0    62.0    75.0
# ...

# %%
# Checking the first 10 rows of the matrix
df[:10]
# Out:
#                    College_name Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
# 5             Albertson College     Yes   587     479     158         38
# 6       Albertus Magnus College     Yes   353     340     103         17
# 7                Albion College     Yes  1899    1720     489         37
# 8              Albright College     Yes  1038     839     227         30
# 9     Alderson-Broaddus College     Yes   582     498     172         21
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# ...

# %%
sns.pairplot(data=df[:10])

# %%
#to produce side-by-side boxplots of Outstate versus Private.
sns.boxplot(y=df['Outstate'],x=df['Private'])

# %% [markdown]
# Create a new qualitative variable, called Elite, by binning
# the Top10perc variable. We are going to divide universities
# into two groups based on whether or not the proportion
# of students coming from the top 10% of their high school
# classes exceeds 50%.

# %%
df['elite'] = np.where(df.Top10perc >= 50, 'Yes', 'No')

# %%
df.head()
# Out:
#                    College_name Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
df['elite'].value_counts()
# Out:
# No     694
# Yes     83
# Name: elite, dtype: int64

# %%
sns.boxplot(y=df['Outstate'],x=df['elite'])

# %%
df.hist(figsize=(12,12));
# Out:
# C:\Users\A691602\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\A691602\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\Users\A691602\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
#Correlation of data
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# we can see there is high correlation fos some features
# Out:
# <style  type="text/css" >
#     #T_8992e19e_4aca_11eb_a05f_f894c299b35crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8992e19e_4aca_11eb_a05f_f894c299b35crow0_col1 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_8992e19e_4aca_11eb_a05f_f894c299b35crow0_col2 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_8992e19e_4aca_11eb_a05f_f894c299b35crow0_col3 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_8992e19e_4aca_11eb_a05f_f894c299b35crow0_col4 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_8992e19e_4aca_11eb_a05f_f894c299b35crow0_col5 {
#             background-color:  #e36c55;
#             color:  #000000;
#         }    #T_8992e19e_4aca_11eb_a05f_f894c299b35crow0_col6 {
#             background-color:  #e4d9d2;
#             color:  #000000;
# ...
